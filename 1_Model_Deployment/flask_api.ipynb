# %%
import joblib

# %%
import joblib

model = joblib.load("intent_classifier.pkl")

def detect_intent(message):
    return model.predict([message])[0]

# %%
intent = detect_intent("what does metasis mean?")
print(intent)
# Out:
# medical_term_query

# %%
print(model.predict("Hi how are you?")[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(model.predict("Hi how are you?")[0])
#
# File ~/AI-ML/venv/lib/python3.12/site-packages/sklearn/pipeline.py:745, in Pipeline.predict(self, X, **params)
#     743 if not _routing_enabled():
#     744     for _, name, transform in self._iter(with_final=False):
# --> 745         Xt = transform.transform(Xt)
#     746     return self.steps[-1][1].predict(Xt, **params)
#     748 # metadata routing enabled
#
# File ~/AI-ML/venv/lib/python3.12/site-packages/sklearn/feature_extraction/text.py:2128, in TfidfVectorizer.transform(self, raw_documents)
#    2111 """Transform documents to document-term matrix.
#    2112
#    2113 Uses the vocabulary and document frequencies (df) learned by fit (or
#    (...)   2124     Tf-idf-weighted document-term matrix.
#    2125 """
#    2126 check_is_fitted(self, msg="The TF-IDF vectorizer is not fitted")
# -> 2128 X = super().transform(raw_documents)
#    2129 return self._tfidf.transform(X, copy=False)
#
# File ~/AI-ML/venv/lib/python3.12/site-packages/sklearn/feature_extraction/text.py:1425, in CountVectorizer.transform(self, raw_documents)
#    1409 """Transform documents to document-term matrix.
#    1410
#    1411 Extract token counts out of raw text documents using the vocabulary
#    (...)   1422     Document-term matrix.
#    1423 """
#    1424 if isinstance(raw_documents, str):
# -> 1425     raise ValueError(
#    1426         "Iterable over raw text documents expected, string object received."
#    1427     )
#    1428 self._check_vocabulary()
#    1430 # use the same matrix-building strategy as fit_transform
#
# ValueError: Iterable over raw text documents expected, string object received.
